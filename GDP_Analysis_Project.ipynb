# %% [markdown]
# # **IMPORTING LIBRARY**

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # **LOADING DATASET**

# %%
gdp_current_price=pd.read_csv("/content/drive/MyDrive/Raw Data Set Decoder/State Wise GDP Dataset 1 Raw data.csv")
gdp_current_price
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %% [markdown]
# # **Making Pivot Table**

# %%
pd.pivot_table(gdp_current_price,index=["Items  Description","Duration"])
# Out:
#                                              All_India GDP  \
# Items  Description                 Duration
# (% Growth over previous year)      2012-13           13.86
#                                    2013-14           12.97
#                                    2014-15           10.65
#                                    2015-16            9.99
#                                    2016-17           11.52
# GSDP - CURRENT PRICES (` in Crore) 2011-12      8736039.00
#                                    2012-13      9946636.00
#                                    2013-14     11236635.00
#                                    2014-15     12433749.00
#                                    2015-16     13675331.00
#                                    2016-17     15251028.00
#
#                                              Andaman & Nicobar Islands  \
# Items  Description                 Duration
# (% Growth over previous year)      2012-13                       11.13
# ...

# %% [markdown]
# # **Removing Nan Value Rows Or Data Cleaning**

# %%
gdp_current_price=gdp_current_price.drop(gdp_current_price.index[[5,10]])
gdp_current_price
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %% [markdown]
# # **Checking For Null Values**

# %%
gdp_current_price.info
# Out:
# <bound method DataFrame.info of                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# ...

# %% [markdown]
# # **Extracting State Names**

# %%
column_attributes=list(gdp_current_price.columns)
column_attributes
# Out:
# ['Items  Description',
#  'Duration',
#  'Andhra Pradesh ',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal1',
#  'Andaman & Nicobar Islands',
#  'Chandigarh',
#  'Delhi',
#  'Puducherry',
#  'All_India GDP']

# %% [markdown]
# # **Removing Oth And 1st Index In The List**

# %%
del(column_attributes[0])
del(column_attributes[0])

# %%
states=column_attributes

# %%
states
# Out:
# ['Andhra Pradesh ',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal1',
#  'Andaman & Nicobar Islands',
#  'Chandigarh',
#  'Delhi',
#  'Puducherry',
#  'All_India GDP']

# %% [markdown]
# # **Creating Average Growth Row And Calculation respective States Mean Value**

# %%
state_mean={}
for column in gdp_current_price:
  if column in states:
    mean=gdp_current_price[gdp_current_price["Items  Description"]=="(% Growth over previous year)"][column].mean()
    state_mean[column]=mean
state_mean["Items  Description"]="Average growth rate"
gdp_current_price=gdp_current_price.append(state_mean,ignore_index=True)

# %%
gdp_current_price
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12      379402.0000
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13      411404.0000
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14      464272.0000
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15      526468.0000
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16      609934.0000
# 5       (% Growth over previous year)  2012-13           8.4300
# 6       (% Growth over previous year)  2013-14          12.8500
# 7       (% Growth over previous year)  2014-15          13.4000
# 8       (% Growth over previous year)  2015-16          15.8500
# 9                 Average growth rate      NaN          12.6325
#
#    Arunachal Pradesh        Assam       Bihar  Chhattisgarh       Goa  \
# 0         11063.0000  143175.0000  247144.000   158074.0000  42367.00
# 1         12547.0000  156864.0000  282368.000   177511.0000  38120.00
# ...

# %%
gdp_current_price=gdp_current_price.iloc[[4,8,9],:]
gdp_current_price
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16      609934.0000
# 8       (% Growth over previous year)  2015-16          15.8500
# 9                 Average growth rate      NaN          12.6325
#
#    Arunachal Pradesh        Assam       Bihar  Chhattisgarh       Goa  \
# 4         18784.0000  224234.0000  413503.000   260776.0000  45002.00
# 8            12.0700      13.1900      10.590       10.9800     10.75
# 9            14.1625      11.8775      13.765       13.3525      2.02
#
#        Gujarat      Haryana  ...    Telangana    Tripura  Uttar Pradesh  \
# 4  994316.0000  485184.0000  ...  575631.0000        NaN   1.153795e+06
# 8      11.0900      10.9100  ...      12.6100        NaN   1.058000e+01
# 9      12.7675      13.0425  ...      12.4975  15.613333   1.236750e+01
#
#    Uttarakhand  West Bengal1  Andaman & Nicobar Islands  Chandigarh  \
# ...

# %% [markdown]
# # **Interchanging Row And Column**

# %%
gdp=gdp_current_price.T
gdp
# Out:
#                                                             4  \
# Items  Description         GSDP - CURRENT PRICES (` in Crore)
# Duration                                              2015-16
# Andhra Pradesh                                       609934.0
# Arunachal Pradesh                                     18784.0
# Assam                                                224234.0
# Bihar                                                413503.0
# Chhattisgarh                                         260776.0
# Goa                                                   45002.0
# Gujarat                                              994316.0
# Haryana                                              485184.0
# Himachal Pradesh                                          NaN
# Jammu & Kashmir                                      118387.0
# Jharkhand                                            241955.0
# Karnataka                                           1027068.0
# ...

# %% [markdown]
# # **Making 0th Row As Header**

# %%
gdp.columns=gdp_columns=gdp.iloc[0]

# %%
gdp
# Out:
# Items  Description         GSDP - CURRENT PRICES (` in Crore)  \
# Items  Description         GSDP - CURRENT PRICES (` in Crore)
# Duration                                              2015-16
# Andhra Pradesh                                       609934.0
# Arunachal Pradesh                                     18784.0
# Assam                                                224234.0
# Bihar                                                413503.0
# Chhattisgarh                                         260776.0
# Goa                                                   45002.0
# Gujarat                                              994316.0
# Haryana                                              485184.0
# Himachal Pradesh                                          NaN
# Jammu & Kashmir                                      118387.0
# Jharkhand                                            241955.0
# Karnataka                                           1027068.0
# ...

# %% [markdown]
# # **Removing 0th And 1st Row**

# %%
gdp=gdp[2:]
gdp
# Out:
# Items  Description        GSDP - CURRENT PRICES (` in Crore)  \
# Andhra Pradesh                                      609934.0
# Arunachal Pradesh                                    18784.0
# Assam                                               224234.0
# Bihar                                               413503.0
# Chhattisgarh                                        260776.0
# Goa                                                  45002.0
# Gujarat                                             994316.0
# Haryana                                             485184.0
# Himachal Pradesh                                         NaN
# Jammu & Kashmir                                     118387.0
# Jharkhand                                           241955.0
# Karnataka                                          1027068.0
# Kerala                                              588337.0
# Madhya Pradesh                                      543975.0
# ...

# %% [markdown]
# # **Extracting Average Growth Rate Column Making Bar PLot Of Average Growth Rate**

# %%
gdp["Average growth rate"].sort_values().plot.bar()

# %% [markdown]
# # Inferences
#
# 1.   Average Rate Of GDP In North East States Like Tripura,Nagaland, Mizoram Is High.
# 2.   States like Goa, Meghalaya, Odisha,Sikkim, Jammu & Kashmir Is Strulling With GDP Growth.
# 3.   All India GDP Is So Relatively Low.
# 4.   GDP Growth Of Bihar,Chattishgarh, Andaman & Nicobar, Andhara Pradesh, Karnataka, Arunachal Pradesh Are relatively High.
# 5.   For All Other States GDP Growth Is Medium.

# %% [markdown]
# # **Making Bar PLot Of Average Growth Rate Of GSDP - CURRENT PRICES (` in Crore)**

# %%
gdp["GSDP - CURRENT PRICES (` in Crore)"].drop("All_India GDP",axis=0).sort_values().plot.bar()

# %% [markdown]
# **INFERENCES**
#
# 1.   States Like Tanil Nadu, Uttar Pradesh, Karnataka, Gujrat Is Very High.
# 2.   States Like Rajasthan, Andhara Pradesh, kerala, Telengana And MadhyaPradesh Are Not That Much High Inspite That They Are Very Big States.
# 3.   States Like Haryana, Bihar, Punjab And Odisha Is Very low.
# 4.   States Like Chattishgarh, Jharkhand, Assam, Jammu And Kashmir And Uttarakhand Are Extermely low As They Have Relatively Big States In Term Of Land.
# 5.   Remaining States Like Goa, Tripura, Meghalay etc Are Low As They Occupy Less Area.

# %% [markdown]
# # **Part-1B**

# %% [markdown]
# # **Importing States Name**

# %%
states
# Out:
# ['Andhra Pradesh ',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal1',
#  'Andaman & Nicobar Islands',
#  'Chandigarh',
#  'Delhi',
#  'Puducherry',
#  'All_India GDP']

# %%
states=['Andhra_Pradesh',
 'Arunachal_Pradesh',
 'Assam',
 'Bihar',
 'Chhattisgarh',
 'Goa',
 'Gujarat',
 'Haryana',
 'Himachal_Pradesh',
 'Jammu & Kashmir',
 'Jharkhand',
 'Karnataka',
 'Kerala',
 'Madhya_Pradesh',
 'Maharashtra',
 'Manipur',
 'Meghalaya',
 'Mizoram',
 'Nagaland',
 'Odisha',
 'Punjab',
 'Rajasthan',
 'Sikkim',
 'Tamil Nadu',
 'Telangana',
 'Tripura',
 'Uttar_Pradesh',
 'Uttarakhand',
 'West Bengal']

# %%
len(states)
# Out:
# 29

# %% [markdown]
# # **Importing Required Library**

# %%
import os

# %% [markdown]
# # **Creating Blank Dataframe**

# %%
gsva=pd.DataFrame()

# %% [markdown]
# # **Assigning Path**

# %%
path=("/content/drive/MyDrive/Raw Data Set Decoder/GDP Part 1b Raw Data/")

# %% [markdown]
# # **Checking All Files Names**

# %%
listoffiles=os.listdir(path)

# %% [markdown]
# # **Iterating all Files And Merging To one File**

# %%
for filename in listoffiles:
  for statename in states:
    if statename in filename:
      filepath=path+filename
      data=pd.read_csv(filepath,encoding="ISO-8859-1")
      data=data[["Item","2014-15"]]
      data=data.T
      data.columns=data.iloc[0]
      data=data[1:]
      data["state"]=statename
      gsva=pd.concat([data,gsva])

# %% [markdown]
# # **Assigning State Colum As Index**

# %%
gsva.set_index("state",inplace=True)

# %%
gsva
# Out:
# Item              Agriculture, forestry and fishing      Crops  Livestock  \
# state
# Tripura                                    799825.0   397591.0    88176.0
# Uttar_Pradesh                              25097754   16215212    7096876
# Uttarakhand                               1601423.0   866146.0   391188.0
# Madhya_Pradesh                             16235647   13216013    1932769
# Nagaland                                     607897     375825     123800
# Meghalaya                                  366521.0   223330.0    72442.0
# Odisha                                      6422978    4382636     788243
# Manipur                                    383140.0   226583.0    75483.0
# Punjab                                      9285716    5690972    2638842
# Rajasthan                                  15044394    7673441    5356257
# Maharashtra                                16475655   10435121    3972829
# Sikkim                                       137447     114976      17338
# ...

# %% [markdown]
# **Making bar Plot Of Per Capita GSDP (Rs.)**

# %%
gsva["Per Capita GSDP (Rs.)"].sort_values().plot.bar()

# %% [markdown]
# # **Ratio Of Bihar To Goa In Term Of GSDP**

# %%
gsva["Per Capita GSDP (Rs.)"].sort_values()["Goa"]/gsva["Per Capita GSDP (Rs.)"].sort_values()["Bihar"]
# Out:
# 8.004741709371503

# %% [markdown]
# # **Assigning Three New column To Know The Contribution Towards GDP**

# %%
gsva["primary_gdp_percent"]=0
gsva["secondary_gdp_percent"]=0
gsva["tertiary_gdp_percent"]=0

# %%
gsva
# Out:
# Item              Agriculture, forestry and fishing      Crops  Livestock  \
# state
# Tripura                                    799825.0   397591.0    88176.0
# Uttar_Pradesh                              25097754   16215212    7096876
# Uttarakhand                               1601423.0   866146.0   391188.0
# Madhya_Pradesh                             16235647   13216013    1932769
# Nagaland                                     607897     375825     123800
# Meghalaya                                  366521.0   223330.0    72442.0
# Odisha                                      6422978    4382636     788243
# Manipur                                    383140.0   226583.0    75483.0
# Punjab                                      9285716    5690972    2638842
# Rajasthan                                  15044394    7673441    5356257
# Maharashtra                                16475655   10435121    3972829
# Sikkim                                       137447     114976      17338
# ...

# %%
for i in range(len(gsva)):
  gsva.iloc[i,37]=gsva.iloc[i,6]/gsva.iloc[i,30]
  gsva.iloc[i,38]=gsva.iloc[i,10]/gsva.iloc[i,30]
  gsva.iloc[i,39]=gsva.iloc[i,26]/gsva.iloc[i,30]

# %%
gsva
# Out:
# Item              Agriculture, forestry and fishing      Crops  Livestock  \
# state
# Tripura                                    799825.0   397591.0    88176.0
# Uttar_Pradesh                              25097754   16215212    7096876
# Uttarakhand                               1601423.0   866146.0   391188.0
# Madhya_Pradesh                             16235647   13216013    1932769
# Nagaland                                     607897     375825     123800
# Meghalaya                                  366521.0   223330.0    72442.0
# Odisha                                      6422978    4382636     788243
# Manipur                                    383140.0   226583.0    75483.0
# Punjab                                      9285716    5690972    2638842
# Rajasthan                                  15044394    7673441    5356257
# Maharashtra                                16475655   10435121    3972829
# Sikkim                                       137447     114976      17338
# ...

# %% [markdown]
# # **Making Stack Bar Chart**

# %%
gsva.sort_values("Per Capita GSDP (Rs.)")[["primary_gdp_percent","secondary_gdp_percent","tertiary_gdp_percent"]].plot(kind="bar",stacked=True)

# %% [markdown]
# # **Macking Another Stack Bar Plot**

# %%
gsva.sort_values("Per Capita GSDP (Rs.)")["Population ('00)"].plot(kind="bar")

# %% [markdown]
# # **INFERENCES**
#
# 1.   For State Which has Low Per Capita Income Has Significant Depend On Primary Resource Where As States Which Have High Per Capita Incom Relaise More On Secondary And teritary.
# 2.   UP Has High GDP But Due To Its Population It Has Low Per Capita Income

# %% [markdown]
# # **Assigning New Variable**

# %%
per_capita=gsva["Per Capita GSDP (Rs.)"].sort_values()

# %% [markdown]
# # **Calculating Quantile**

# %%
per_capita.quantile([0.20,0.5,0.8,1])
# Out:
# 0.2     62989.0
# 0.5    101332.0
# 0.8    152853.0
# 1.0    271793.0
# Name: Per Capita GSDP (Rs.), dtype: object

# %%
per_capita.sort_values(ascending=False)
# Out:
# state
# Goa                    271793
# Sikkim                 240274
# Haryana              164077.0
# Kerala                 154778
# Uttarakhand          153076.0
# Maharashtra            152853
# Himachal_Pradesh       147330
# Karnataka              145141
# Gujarat              141263.0
# Telangana              139035
# Punjab                 126606
# Arunachal_Pradesh      112718
# Andhra_Pradesh         104977
# Mizoram                 97687
# Nagaland                89607
# Chhattisgarh            86860
# Rajasthan               84837
# Tripura               77358.0
# Meghalaya             76228.0
# Odisha                  73979
# Madhya_Pradesh          62989
# Jharkhand               62091
# Assam                   60621
# Manipur               58442.0
# Uttar_Pradesh           49450
# Bihar                   33954
# Name: Per Capita GSDP (Rs.), dtype: object

# %% [markdown]
# # **Dividing Into Four Category Based On Per capita**

# %%
category_1=["Goa","Sikkim","Kerala","Haryana"]
category_2=["Arunachal_Pradesh","Punjab","Telangana","Gujarat","Karnataka","Maharashtra","Uttarakhand"]
category_3=["Madhya_Pradesh","Odisha","Meghalaya","Tripura","Rajasthan","Chhattisgarh","Nagaland","Andhra_Pradesh"]
category_4=["Bihar","Uttar_Pradesh","Manipur","Assam","Jharkhand"]

Categories_columns=["Agriculture, forestry and fishing","Mining and quarrying","Manufacturing","Electricity, gas, water supply & other utility services",
                    "Construction","Trade, repair, hotels and restaurants","Transport, storage, communication & services related to broadcasting",
                    "Financial services", "Real estate, ownership of dwelling & professional services","Public administration","Other services",
                    "Taxes on Products","Subsidies on products"]

# %% [markdown]
# # **CATEGORY 1**

# %%
agg=gsva.loc[category_1,Categories_columns].sum()

# %%
agg_gsdp=gsva.loc[category_1,"Gross State Domestic Product"].sum()

# %%
agg
# Out:
# Item
# Agriculture, forestry and fishing                                       14391809.0
# Mining and quarrying                                                      588961.0
# Manufacturing                                                           13758793.0
# Electricity, gas, water supply & other utility services                  2000998.0
# Construction                                                            11264451.0
# Trade, repair, hotels and restaurants                                   13995159.0
# Transport, storage, communication & services related to broadcasting     6818560.0
# Financial services                                                       3936489.0
# Real estate, ownership of dwelling & professional services              14740245.0
# Public administration                                                    3571292.0
# Other services                                                           8059922.0
# ...

# %%
agg_gsdp
# Out:
# 101930677.0

# %% [markdown]
# # **Calculating Each Sector Proportion To Total GDP**

# %%
proportion=100*agg/agg_gsdp

# %%
proportion.sort_values(ascending=False)[0:6].plot.bar()

# %% [markdown]
# # **RECOMENDATION**
#
# 1.   Thre Are Only Four States In This Category, All Of Which Are Small in Are Wise And Have Good Industrial Base, Agricultural, Trade And Real Estate.
# 2.   Trade And Hospitality Bussiness Shoul Be Promoted Further.
# 3.   Manufacturing Should Be Further Promoted.

# %% [markdown]
# # **Category 2 States**

# %%
agg=gsva.loc[category_2,Categories_columns].sum()
agg_gsdp=gsva.loc[category_2,"Gross State Domestic Product"].sum()
proportion2=100*agg/agg_gsdp
proportion2.sort_values(ascending=False)[0:6].plot.bar()

# %% [markdown]
# # **RECOMENDATION**
#
# 1.   These State Have Relatively Good Per Capita GDP and Are Driven By Equal Percentage By Industries And Agriculture. These Implies That These States Have Pool Of Talent To Drive Industries And Agriculture. Because Of The Talent, Other Industries CAn Take Advantage And Setup Good Industries.
# 2.   States Like Karnataka, Tamil Nadu, Gijarat And Maharastra Which HAs Huge Coastal Area Can Setup Ports. Coastal Area Can Help  In Harness Clean Energy And Fishries Can Be Incrised. Similarly, Tourism Industry Should Also Be Incouraged.

# %% [markdown]
# # **Category 3 States**

# %%
agg=gsva.loc[category_3,Categories_columns].sum()
agg_gsdp=gsva.loc[category_3,"Gross State Domestic Product"].sum()
proportion3=100*agg/agg_gsdp
proportion3.sort_values(ascending=False)[0:6].plot.bar()

# %% [markdown]
# # **Category 4 States**

# %%
agg=gsva.loc[category_4,Categories_columns].sum()
agg_gsdp=gsva.loc[category_4,"Gross State Domestic Product"].sum()
proportion4=100*agg/agg_gsdp
proportion4.sort_values(ascending=False)[0:6].plot.bar()

# %% [markdown]
# # **PART2**

# %% [markdown]
# # **IMPORTING DATA AND STORING IN NEW DATA FRAME**

# %%
drop_out_rate=pd.read_csv("/content/drive/MyDrive/Raw Data Set Decoder/rs_session243_au570_1.1-1.csv",index_col=0)

# %%
drop_out_rate
# Out:
#           Level of Education - State  Primary - 2012-2013  \
# Sl. No.
# 1                      A & N Islands                 0.68
# 2                     Andhra Pradesh                 3.18
# 3                  Arunachal Pradesh                15.16
# 4                              Assam                 6.24
# 5                              Bihar                  NaN
# 6                         Chandigarh                  NaN
# 7                        Chhatisgarh                 4.14
# 8               Dadra & Nagar Haveli                  NaN
# 9                        Daman & Diu                  NaN
# 10                             Delhi                  NaN
# 11                               Goa                  NaN
# 12                           Gujarat                 0.74
# 13                           Haryana                 1.29
# 14                  Himachal Pradesh                 0.45
# 15                 Jammu and Kashmir                 6.30
# ...

# %%
drop_out_rate.replace({"Andhra Pradesh":"Andhra_Pradesh","Arunachal Pradesh":"Arunachal_Pradesh",
                       "Uttar Pradesh":"Uttar_Pradesh","Madhya Pradesh":"Madhya_Pradesh"},inplace=True)

# %%
drop_out_rate
# Out:
#           Level of Education - State  Primary - 2012-2013  \
# Sl. No.
# 1                      A & N Islands                 0.68
# 2                     Andhra_Pradesh                 3.18
# 3                  Arunachal_Pradesh                15.16
# 4                              Assam                 6.24
# 5                              Bihar                  NaN
# 6                         Chandigarh                  NaN
# 7                        Chhatisgarh                 4.14
# 8               Dadra & Nagar Haveli                  NaN
# 9                        Daman & Diu                  NaN
# 10                             Delhi                  NaN
# 11                               Goa                  NaN
# 12                           Gujarat                 0.74
# 13                           Haryana                 1.29
# 14                  Himachal Pradesh                 0.45
# 15                 Jammu and Kashmir                 6.30
# ...

# %% [markdown]
# # **CHANGING COLUMN NAME**

# %%
drop_out_rate.rename(columns={"Level of Education - State":"State"},inplace=True)

# %%
drop_out_rate=drop_out_rate.set_index("State")

# %% [markdown]
# # **MERGING GSVA  AND DROP OUT RATE DATABASE**

# %%
gsva_drop=pd.merge(gsva,drop_out_rate,how="inner",left_index=True,right_index=True)

# %%
gsva_drop.columns
# Out:
# Index(['Agriculture, forestry and fishing', 'Crops', 'Livestock',
#        'Forestry and logging', 'Fishing and aquaculture',
#        'Mining and quarrying', 'Primary', 'Manufacturing',
#        'Electricity, gas, water supply & other utility services',
#        'Construction', 'Secondary', 'Trade, repair, hotels and restaurants',
#        'Trade & repair services', 'Hotels & restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Railways', 'Road transport', 'Water transport', 'Air transport',
#        'Services incidental to transport*', 'Storage',
#        'Communication & services related to broadcasting',
#        'Financial services',
#        'Real estate, ownership of dwelling & professional services',
#        'Public administration', 'Other services', 'Tertiary',
#        'TOTAL GSVA at basic prices', 'Taxes on Products',
#        'Subsidies on products', 'Gross State Domestic Product',
# ...

# %% [markdown]
# # **EXTRACTING TWO COLUMN**

# %%
gsva_primary=gsva_drop[["Per Capita GSDP (Rs.)","Primary - 2014-2015"]]
gsva_primary
# Out:
#                   Per Capita GSDP (Rs.)  Primary - 2014-2015
# Tripura                         77358.0                 3.58
# Uttar_Pradesh                     49450                 7.08
# Madhya_Pradesh                    62989                10.14
# Nagaland                          89607                19.41
# Meghalaya                       76228.0                10.34
# Odisha                            73979                 2.94
# Manipur                         58442.0                18.00
# Punjab                           126606                 1.29
# Rajasthan                         84837                 8.39
# Maharashtra                      152853                 0.55
# Sikkim                           240274                 4.57
# Mizoram                           97687                12.96
# Telangana                        139035                 5.81
# Arunachal_Pradesh                112718                10.89
# ...

# %%
gsva_primary.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
gsva_primary
# Out:
#                   Per Capita GSDP (Rs.)  Primary - 2014-2015
# Tripura                         77358.0                 3.58
# Uttar_Pradesh                     49450                 7.08
# Madhya_Pradesh                    62989                10.14
# Nagaland                          89607                19.41
# Meghalaya                       76228.0                10.34
# Odisha                            73979                 2.94
# Manipur                         58442.0                18.00
# Punjab                           126606                 1.29
# Rajasthan                         84837                 8.39
# Maharashtra                      152853                 0.55
# Sikkim                           240274                 4.57
# Mizoram                           97687                12.96
# Telangana                        139035                 5.81
# Arunachal_Pradesh                112718                10.89
# ...

# %% [markdown]
# # **CONVERTING FLOAT VALUE TO INT**

# %%
gsva_primary["Primary - 2014-2015"]=gsva_primary["Primary - 2014-2015"].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
gsva_primary
# Out:
#                   Per Capita GSDP (Rs.)  Primary - 2014-2015
# Tripura                         77358.0                    3
# Uttar_Pradesh                     49450                    7
# Madhya_Pradesh                    62989                   10
# Nagaland                          89607                   19
# Meghalaya                       76228.0                   10
# Odisha                            73979                    2
# Manipur                         58442.0                   18
# Punjab                           126606                    1
# Rajasthan                         84837                    8
# Maharashtra                      152853                    0
# Sikkim                           240274                    4
# Mizoram                           97687                   12
# Telangana                        139035                    5
# Arunachal_Pradesh                112718                   10
# ...

# %% [markdown]
# # **PLOTTING A GRAPH**

# %%
import matplotlib.pyplot as plt

# %%
gsva_primary.plot.scatter(x=["Per Capita GSDP (Rs.)"],y=["Primary - 2014-2015"])

# %%
gsva_secondary=gsva_drop[["Per Capita GSDP (Rs.)","Secondary - 2014-2015"]]
gsva_secondary.dropna(inplace=True)
gsva_secondary["Secondary - 2014-2015"]=gsva_secondary["Secondary - 2014-2015"].astype(int)
gsva_secondary.plot.scatter(x=["Per Capita GSDP (Rs.)"],y=["Secondary - 2014-2015"])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
